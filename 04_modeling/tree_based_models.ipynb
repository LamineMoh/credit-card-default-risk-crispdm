# %%
import pandas as pd
import numpy as np

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, recall_score
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier

# %%
df = pd.read_csv(r"C:\Users\zouta\Desktop\Projets\Default Of Credit Cards Clients\data\processed\credit_default_features.csv")

X = df.drop(columns=["default payment next month"])
y = df["default payment next month"]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    test_size=0.2,
    stratify=y,
    random_state=42
)

# %%
rf = RandomForestClassifier(
    n_estimators=200,
    class_weight="balanced",
    random_state=42
)

rf.fit(X_train, y_train)
y_pred_rf = rf.predict(X_test)

print("Random Forest Recall:", recall_score(y_test, y_pred_rf))
print(classification_report(y_test, y_pred_rf))
# Out:
# Random Forest Recall: 0.3413715146948003
#               precision    recall  f1-score   support
#
#            0       0.83      0.94      0.89      4673
#            1       0.63      0.34      0.44      1327
#
#     accuracy                           0.81      6000
#    macro avg       0.73      0.64      0.66      6000
# weighted avg       0.79      0.81      0.79      6000

# %%
gb = GradientBoostingClassifier(random_state=42)

gb.fit(X_train, y_train)
y_pred_gb = gb.predict(X_test)

print("Gradient Boosting Recall:", recall_score(y_test, y_pred_gb))
print(classification_report(y_test, y_pred_gb))
# Out:
# Gradient Boosting Recall: 0.36096458176337604
#               precision    recall  f1-score   support
#
#            0       0.84      0.95      0.89      4673
#            1       0.67      0.36      0.47      1327
#
#     accuracy                           0.82      6000
#    macro avg       0.76      0.66      0.68      6000
# weighted avg       0.80      0.82      0.80      6000

# %% [markdown]
# ## Model Comparison Summary
#
# - Logistic Regression provides interpretability and stability.
# - Tree-based models capture non-linear relationships.
# - Gradient Boosting often improves recall but reduces interpretability.
#
# Model choice depends on the trade-off between performance and explainability.
